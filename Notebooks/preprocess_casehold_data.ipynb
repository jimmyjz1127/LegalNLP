# %%
# !pip3 install tqdm
# !pip3 install argparse
# !pip3 install collections
# !pip3 install datasets
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.3 MB/s eta 0:00:00
# ...

# %%
import os
import json
import re
import string
import random
import time
import datetime

import numpy as np
import pandas as pd

from argparse import Namespace
from tqdm import tqdm_notebook
from datasets import Dataset

# import transformers
# from transformers import BertTokenizer, BertModel
# from transformers import AutoTokenizer, AutoModelForMaskedLM

# import torch.nn.functional as F
# import torch

# from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
# from sklearn.feature_extraction import text
# from sklearn.metrics.pairwise import cosine_similarity, linear_kernel

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
args = Namespace(
    processed_data_path = "/content/drive/MyDrive/Colab_Notebooks/CS4099-LegalNLP/processed_data/",
    max_samples = 10,
    mode = 'a', # a : append, w : write,
)

# %%
casehold_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/CS4099-LegalNLP/raw_data/casehold.csv')

# %%
contexts = []
holdings = []
binary_labels = []
relevance_labels = []


for index, row in casehold_df.iterrows():
  context = row['1']
  holding_index = row['12']

  for i in range(2,7):
    holding = row[i]
    contexts.append(context)
    holdings.append(holding)
    binary_labels.append(1 if i == int(holding_index) + 2 else 0)
    relevance_labels.append(row[i + 5] if row[i+5] != 0 else 1)

processed_df = pd.DataFrame({'context' : contexts, 'holding':holdings, 'binary_label' : binary_labels, 'relevance_label':relevance_labels})

# %%
processed_df.head()
# Out:
#                                              context  \
# 0  Drapeau’s cohorts, the cohort would be a “vict...
# 1  Drapeau’s cohorts, the cohort would be a “vict...
# 2  Drapeau’s cohorts, the cohort would be a “vict...
# 3  Drapeau’s cohorts, the cohort would be a “vict...
# 4  Drapeau’s cohorts, the cohort would be a “vict...
#
#                                              holding  binary_label  \
# 0  holding that possession of a pipe bomb is a cr...             1
# 1  holding that bank robbery by force and violenc...             0
# 2  holding that sexual assault of a child qualifi...             0
# 3  holding for the purposes of 18 usc  924e that ...             0
# 4  holding that a court must only look to the sta...             0
#
#    relevance_label
# 0            1.000
# 1            0.652
# 2            0.647
# 3            0.670
# 4            0.639

# %%
processed_df.to_csv(args.processed_data_path + '/casehold_processed.csv', mode=args.mode)
